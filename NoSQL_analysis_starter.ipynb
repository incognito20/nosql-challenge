# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
#Assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
#Review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
#Assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645bbbf15c9ad14c728dc016'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Use count_documents to display the number of documents in the result
hygiene_count = establishments.count_documents({'scores.Hygiene': 20})
pprint(hygiene_count)
# Out:
# 41

# %%
# Display the first document in the results using pprint
first_hygiene = establishments.find({'scores.Hygiene': 20})
pprint(first_hygiene[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645bbbf15c9ad14c728dc016'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Convert the result to a Pandas DataFrame
query = {'scores.Hygiene': 20}
results = establishments.find(query)
results_df = pd.DataFrame(results)

# %%
# Display the number of rows in the DataFrame
len(results_df.index)
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645bbbf15c9ad14c728dc016   110681                  0
# 1  645bbbf15c9ad14c728dc399   612039                  0
# 2  645bbbf15c9ad14c728dc6a3   730933                  0
# 3  645bbbf15c9ad14c728dc891   172735                  0
# 4  645bbbf15c9ad14c728dc8a1   172953                  0
# 5  645bbbf15c9ad14c728dd23d   512854                  0
# 6  645bbbf15c9ad14c728dd461  1537089                  0
# 7  645bbbf15c9ad14c728de98b   155648                  0
# 8  645bbbf15c9ad14c728dedd0  1012883                  0
# 9  645bbbf15c9ad14c728df5e0   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': {'$regex': "City of London Corporation"}, 'RatingValue': {'$gte': 4}}

# Capture the results to a variable
results = establishments.find(query)


# Pretty print the results
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645bbbf15c9ad14c728dda34'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Use count_documents to display the number of documents in the result
london_gtefour = establishments.count_documents({'LocalAuthorityName': {'$regex': "City of London Corporation"}, 'RatingValue': {'$gte': 4}})
print(london_gtefour)
# Out:
# 33

# %%
# Display the first document in the results using pprint
first_london_gtefour = establishments.find({'LocalAuthorityName': {'$regex': "City of London Corporation"}, 'RatingValue': {'$gte': 4}})
pprint(first_london_gtefour[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645bbbf15c9ad14c728dda34'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Find London with rating value of 4 or higher and conver to dataframe.
query = {'LocalAuthorityName': {'$regex': "City of London Corporation"}, 'RatingValue': {'$gte': 4}}
london = establishments.find(query)
london_df = pd.DataFrame(london)

# %%
# Number of rows in the dataframe
len(london_df.index)
# Out:
# 33

# %%
# Print the first 10 rows of the dataframe
london_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645bbbf15c9ad14c728dda34   621707                  0
# 1  645bbbf15c9ad14c728ddd59  1130836                  0
# 2  645bbbf15c9ad14c728de8a7   293783                  0
# 3  645bbbf15c9ad14c728df6a4   294474                  0
# 4  645bbbf15c9ad14c728df6a7  1315095                  0
# 5  645bbbf15c9ad14c728dfdaf   294900                  0
# 6  645bbbf25c9ad14c728e1ebc   293756                  0
# 7  645bbbf25c9ad14c728e2283   878523                  0
# 8  645bbbf25c9ad14c728e229f   293772                  0
# 9  645bbbf25c9ad14c728e22a0   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000014647              Tilbury Seafarers Centre
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# Sets the variables for Penang Flavours location and search area
degree_search = 0.01
longitude = 0.08384000
latitude = 51.49014200


# Queries based on rating, latitude, and longitude
match_query = {'$match': {'RatingValue': 5,
                          'geocode.longitude': {'$gte': longitude - degree_search, '$lt': longitude + degree_search},
                          'geocode.latitude': {'$gte': latitude - degree_search, '$lt': latitude + degree_search},
    
                         }
}

# Groups by rating
group_query = {'$group': {'RatingValue': 5}
               }

# Create a dictionary that will allow the pipeline to sort by count in descending order
sort_values = {'$sort': {'scores.Hygiene': -1 }}

# Puts the pipeline together
pipeline = [match_query, sort_values]
p_results = list(establishments.aggregate(pipeline))


#Prints the results
pprint(p_results[0:5])
# Out:
# [{'AddressLine1': '152 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.930146257832,
#   'FHRSID': 1069652,
#   'LocalAuthorityBusinessID': 'PI/000206841',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2020-10-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('645bbbf25c9ad14c728e183b'),
#   'geocode': {'latitude': Decimal128('51.4870351'),
#               'longitude': Decimal128('0.0927429')},
# ...

# %%
# Convert result to Pandas DataFrame
close_Penang_df = pd.DataFrame(p_results[0:5])

# %%
# Number of rows in the dataframe
len(close_Penang_df.index)
# Out:
# 5

# %%
# Prints the first 10 rows of the dataframe
close_Penang_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645bbbf25c9ad14c728e183b  1069652                  0
# 1  645bbbf25c9ad14c728e1900   694606                  0
# 2  645bbbf25c9ad14c728e1917   695287                  0
# 3  645bbbf25c9ad14c728e1932   695566                  0
# 4  645bbbf25c9ad14c728e193f   695033                  0
#
#   LocalAuthorityBusinessID                        BusinessName  \
# 0             PI/000206841  TIWA N TIWA African Restaurant Ltd
# 1             PI/000116584                Fineway Cash & Carry
# 2             PI/000182135                   Lucky Food & Wine
# 3             PI/000188497                     Premier Express
# 4             PI/000172986                  Everest Stores Ltd
#
#               BusinessType  BusinessTypeID               AddressLine1  \
# 0  Restaurant/Cafe/Canteen               1  152 Plumstead High Street
# 1        Retailers - other            4613  112 Plumstead High Street
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Query looks for Hygiene of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# Groups by LA name and count
group_query = {'$group': {'_id': "$LocalAuthorityName", 'count': { '$sum': 1 }}}

# Create a dictionary that will allow the pipeline to sort by count in descending order
sort_values = {'$sort': { 'count': -1 }}

# Put the pipeline together
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))
# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
# Display the number of rows in the DataFrame
# Display the first 10 rows of the DataFrame
hygiene_df = pd.DataFrame(results[0:10])
print("Rows in DataFrame: ", len(hygiene_df))
hygiene_df.head(10)
# Out:
# Rows in DataFrame:  10
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
